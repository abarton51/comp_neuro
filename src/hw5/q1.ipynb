# %%
import sys
sys.path.append('../')

# %%
from neuro_models.hopfield import Hopfield, HopfieldSimulator

# %%
param = {
    'N': [16],
    'k': [3]
}

simulator = HopfieldSimulator(num_networks=100, param=param)

results = simulator.run_simulation()

# %%
param = {
    'N': [64],
    'k': [6]
}

simulator = HopfieldSimulator(num_networks=100, param=param)

results = simulator.run_simulation()

# %%
param = {
    'N': [225],
    'k': [10]
}

simulator = HopfieldSimulator(num_networks=100, param=param)

results = simulator.run_simulation()
